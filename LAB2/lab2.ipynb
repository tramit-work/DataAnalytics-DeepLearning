# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('processed_dulieuxettuyendaihoc.csv')
df.head()
# Out:
#    STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 0    1  7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  7.00  7.54  7.01
# 1    2  5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...  4.69  5.47  5.07
# 2    3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  5.77  5.38  6.04
# 3    4  6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  6.21  5.20  6.88
# 4    5  6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...  6.50  6.36  6.99
#
#    XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# 0    K    K    K    2.800    3.016    2.804   0.0
# 1    Y   TB   TB    1.876    2.188    2.028   0.0
# 2   TB   TB   TB    2.308    2.152    2.416   1.0
# 3   TB   TB    K    2.484    2.080    2.752   0.0
# 4    K   TB    K    2.600    2.544    2.796   0.0
#
# [5 rows x 66 columns]

# %%
df_sorted = df.sort_values('DH1')
print(df_sorted)
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 53   54  4.9  5.9  6.2  5.6  5.9  5.0  7.0  5.6  6.1  ...  5.69  6.26  6.02
# 43   44  6.6  7.2  5.9  6.9  7.6  8.1  7.3  6.7  6.3  ...  7.05  6.61  6.77
# 72   73  5.5  6.6  7.2  7.6  5.5  6.7  6.7  5.2  6.0  ...  6.20  5.88  6.22
# 5     6  9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  ...  7.96  8.54  7.38
# 87   88  7.3  4.3  5.3  5.8  4.9  3.7  5.6  5.3  5.9  ...  5.44  5.78  6.48
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 84   85  8.4  7.4  6.0  7.8  6.3  7.2  8.5  6.0  9.3  ...  7.23  7.77  7.58
# 11   12  7.9  7.0  9.1  8.6  6.1  7.0  5.6  9.0  8.2  ...  7.43  7.72  7.49
# 23   24  5.3  6.3  5.7  6.9  5.9  7.5  6.6  5.1  6.4  ...  6.05  6.32  6.71
# 24   25  2.4  4.1  3.6  5.5  5.9  5.6  4.9  4.2  3.3  ...  4.45  4.88  5.41
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  7.05  7.84  7.67
#
#     XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# ...

# %%
df_sorted_gender = df.sort_values(['GT', 'DH2'])
print(df_sorted_gender)
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 95   96  8.6  6.9  7.4  8.8  7.6  5.8  7.3  5.7  8.9  ...  7.43  7.42  6.83
# 25   26  3.6  5.8  6.9  6.1  5.5  7.2  5.5  4.3  4.2  ...  5.40  5.20  5.09
# 24   25  2.4  4.1  3.6  5.5  5.9  5.6  4.9  4.2  3.3  ...  4.45  4.88  5.41
# 46   47  6.7  6.8  6.4  5.9  5.6  6.4  8.0  6.8  6.6  ...  6.49  6.51  6.16
# 13   14  4.9  5.4  5.0  5.0  5.8  7.0  4.2  5.8  4.5  ...  5.38  5.51  6.26
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 68   69  7.3  6.4  6.9  7.5  6.2  8.4  7.6  8.1  8.1  ...  7.19  7.70  8.00
# 11   12  7.9  7.0  9.1  8.6  6.1  7.0  5.6  9.0  8.2  ...  7.43  7.72  7.49
# 47   48  7.9  7.6  8.4  8.6  6.2  7.5  8.7  7.7  7.3  ...  7.67  7.49  7.11
# 2     3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  5.77  5.38  6.04
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  7.05  7.84  7.67
#
#     XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# ...

# %%
pivot_dh1_kt = df.pivot_table(values='DH1', index='KT', aggfunc=['count', 'sum', 'mean', 'median', 'min', 'max', 'std', 'quantile'])
print(pivot_dh1_kt)
# Out:
#    count     sum      mean median   min   max       std quantile
#      DH1     DH1       DH1    DH1   DH1   DH1       DH1      DH1
# KT
# A     49  163.50  3.336735   3.25  1.00  6.50  1.274296     3.25
# A1     6   17.50  2.916667   3.00  2.00  4.25  0.861201     3.00
# B      9   29.50  3.277778   3.50  1.75  4.50  0.823905     3.50
# C     14   79.25  5.660714   5.25  4.75  7.00  0.812209     5.25
# D1    22   84.25  3.829545   3.75  1.25  6.75  1.370146     3.75

# %%
pivot_dh1_kt_kv = df.pivot_table(values='DH1', index=['KT', 'KV'], aggfunc=['count', 'sum', 'mean', 'median', 'min', 'max', 'std', 'quantile'])
print(pivot_dh1_kt_kv)
# Out:
#        count    sum      mean median   min   max       std quantile
#          DH1    DH1       DH1    DH1   DH1   DH1       DH1      DH1
# KT KV
# A  1      29  93.75  3.232759  3.250  1.00  6.50  1.369194    3.250
#    2       9  31.75  3.527778  3.500  2.00  6.25  1.427653    3.500
#    2NT    11  38.00  3.454545  3.500  2.00  4.75  0.913908    3.500
# A1 1       2   4.75  2.375000  2.375  2.00  2.75  0.530330    2.375
#    2NT     4  12.75  3.187500  3.250  2.00  4.25  0.921389    3.250
# B  1       8  25.75  3.218750  3.375  1.75  4.50  0.860207    3.375
#    2NT     1   3.75  3.750000  3.750  3.75  3.75       NaN    3.750
# C  1       8  43.50  5.437500  5.250  4.75  7.00  0.728869    5.250
#    2       2  11.50  5.750000  5.750  5.00  6.50  1.060660    5.750
#    2NT     4  24.25  6.062500  6.000  5.25  7.00  0.943729    6.000
# D1 1      13  46.75  3.596154  3.500  1.50  5.75  1.264658    3.500
#    2       8  33.75  4.218750  4.500  1.25  6.75  1.617082    4.500
# ...

# %%
pivot_dh1_kt_kv_dt = df.pivot_table(values='DH1', index=['KT', 'KV', 'DT'], aggfunc=['count', 'sum', 'mean', 'median', 'min', 'max', 'std', 'quantile'])
print(pivot_dh1_kt_kv_dt)
# Out:
#            count    sum      mean median   min   max       std quantile
#              DH1    DH1       DH1    DH1   DH1   DH1       DH1      DH1
# KT KV  DT
# A  1   0.0    29  93.75  3.232759  3.250  1.00  6.50  1.369194    3.250
#    2   0.0     8  27.50  3.437500  3.000  2.00  6.25  1.498511    3.000
#        6.0     1   4.25  4.250000  4.250  4.25  4.25       NaN    4.250
#    2NT 0.0    11  38.00  3.454545  3.500  2.00  4.75  0.913908    3.500
# A1 1   0.0     2   4.75  2.375000  2.375  2.00  2.75  0.530330    2.375
#    2NT 0.0     4  12.75  3.187500  3.250  2.00  4.25  0.921389    3.250
# B  1   0.0     8  25.75  3.218750  3.375  1.75  4.50  0.860207    3.375
#    2NT 0.0     1   3.75  3.750000  3.750  3.75  3.75       NaN    3.750
# C  1   0.0     8  43.50  5.437500  5.250  4.75  7.00  0.728869    5.250
#    2   0.0     2  11.50  5.750000  5.750  5.00  6.50  1.060660    5.750
#    2NT 0.0     4  24.25  6.062500  6.000  5.25  7.00  0.943729    6.000
# ...

# %% [markdown]
# ### PHAN 2

# %%
gt_freq = df["GT"].value_counts()
plt.figure(figsize=(10,5))
sns.barplot(x=gt_freq.index, y=gt_freq.values)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.pie(gt_freq, labels=gt_freq.index, autopct="%1.1f%%", colors=["blue", "red"])
plt.show()

# %%
df[['US_TBM1', 'US_TBM2', 'US_TBM3']].describe().T
# Out:
#          count     mean       std    min    25%    50%    75%    max
# US_TBM1  100.0  2.43448  0.391203  1.616  2.107  2.480  2.724  3.232
# US_TBM2  100.0  2.55960  0.377656  1.768  2.223  2.588  2.893  3.416
# US_TBM3  100.0  2.67176  0.299810  1.916  2.473  2.706  2.874  3.316

# %%
male_students = df[df['GT'] == 'M']
dt_male_students = male_students['DT'].value_counts()
print(dt_male_students)
# Out:
# DT
# 0.0    50
# 1.0     1
# 6.0     1
# Name: count, dtype: int64

# %%
data_male_students = df[(df['GT'] == 'M') & (df['DH1'] >= 5.0) & (df['DH2'] >= 4.0) & (df['DH3'] >= 4.0)]
kv_el_males = data_male_students['KV'].value_counts()
print(kv_el_males)
# Out:
# KV
# 1      2
# 2      2
# 2NT    2
# Name: count, dtype: int64

# %%
region_2NT = df[(df['KV'] == '2NT') & (df['DH1'] >= 5.0) & (df['DH2'] >= 5.0) & (df['DH3'] >= 5.0)]
print(region_2NT)
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 23   24  5.3  6.3  5.7  6.9  5.9  7.5  6.6  5.1  6.4  ...  6.05  6.32  6.71
#
#     XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# 23   TB   TB    K     2.42    2.528    2.684   1.0
#
# [1 rows x 66 columns]

# %% [markdown]
# ###PHAN 3

# %%
female_students = df[df['GT'] == 'F']
xl_cols = ['XL1', 'XL2', 'XL3']

plt.figure(figsize=(12, 6))
for i, xl in enumerate(xl_cols, 1):
    plt.subplot(1, 3, i)
    sns.countplot(data=female_students, x=xl, palette='cool')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-44-0758a377a34b>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=female_students, x=xl, palette='cool')
# <ipython-input-44-0758a377a34b>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=female_students, x=xl, palette='cool')
# <ipython-input-44-0758a377a34b>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=female_students, x=xl, palette='cool')

# %%
df_filtered = df[(df['KT'].isin(['A', 'A1', 'B'])) & (df['KV'].isin(['1', '2']))]
plt.figure(figsize=(10, 6))
sns.countplot(data=df_filtered, x='KT', hue='KQXT', palette='viridis')
plt.legend(title='KQXT')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='KV', hue='KT', palette='pastel')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='KT', hue='KQXT', palette='coolwarm')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='KV', hue='KQXT', palette='plasma')
plt.legend(title='KQXT')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='DT', hue='KQXT', palette='cividis')
plt.legend(title='KQXT')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='GT', hue='KQXT', palette='rocket')
plt.legend(title='KQXT')
plt.show()

# %% [markdown]
# ###PHAN 4

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df['T1'], marker='')
plt.grid()
plt.show()

# %%
def classify_t1(score):
    if score < 5:
        return 'k'
    elif score < 7:
        return 'tb'
    elif score < 8:
        return 'k'
    else:
        return 'g'

df['phanloait1'] = df['T1'].apply(classify_t1)

# %%
fre_table = df['phanloait1'].value_counts()
print(fre_table)
# Out:
# phanloait1
# tb    46
# k     42
# g     12
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x=df.index, y='T1', hue='phanloait1', marker='o')
plt.ylabel('T1')
plt.show()

# %%
plt.figure(figsize=(10, 6))
for category in df['phanloait1'].unique():
    subset = df[df['phanloait1'] == category]
    plt.vlines(x=subset.index, ymin=0, ymax=subset['T1'], colors='r', linestyles='dotted')
plt.scatter(df.index, df['T1'], c='b', label='T1')
plt.ylabel('T1')
plt.legend()
plt.show()

# %%
t1_desc = df['T1'].describe()
print(t1_desc)
# Out:
# count    100.000000
# mean       5.946000
# std        1.608338
# min        2.400000
# 25%        5.000000
# 50%        5.850000
# 75%        7.200000
# max        9.300000
# Name: T1, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['T1'], color='lightblue')
plt.ylabel("T1")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['T1'], bins=20, kde=True, color='blue')
plt.show()

# %%
import scipy.stats as stats
plt.figure(figsize=(8, 6))
stats.probplot(df['T1'], dist="norm", plot=plt)
plt.show()

# %%
skewness = df['T1'].skew()
kurtosis = df['T1'].kurt()
print(skewness)
print(kurtosis)
# Out:
# -0.17824317486762223
# -0.48010360836580634

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['phanloait1'], y=df['T1'], palette='coolwarm')
plt.show()
# Out:
# <ipython-input-96-a4f200ff3532>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['phanloait1'], y=df['T1'], palette='coolwarm')

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='T1', hue='phanloait1', bins=20, kde=True)
plt.show()

# %%
categories = df['phanloait1'].unique()
plt.figure(figsize=(12, 6))
for category in categories:
    stats.probplot(df[df['phanloait1'] == category]['T1'], dist="norm", plot=plt)
plt.show()

# %%
import numpy as np

covariance = np.cov(df['T1'], df['DH1'])[0, 1]
correlation = np.corrcoef(df['T1'], df['DH1'])[0, 1]
print(covariance)
print(correlation)
# Out:
# 0.11283838383838381
# 0.04925439216104145

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['T1'], y=df['DH1'], alpha=0.6)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.lmplot(data=df, x='T1', y='DH1', hue='KV', markers=['o', 's', 'D'])
plt.show()

# %%
correlation_matrix = df[['DH1', 'DH2', 'DH3']].corr()
print(correlation_matrix)
# Out:
#           DH1       DH2       DH3
# DH1  1.000000  0.035154  0.018731
# DH2  0.035154  1.000000 -0.091523
# DH3  0.018731 -0.091523  1.000000

# %%
sns.pairplot(df[['DH1', 'DH2', 'DH3']])
plt.show()
